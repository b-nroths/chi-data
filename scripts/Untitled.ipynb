# %%
import matplotlib
# matplotlib.use('Agg')
import osmnx as ox

# %matplotlib inline
ox.config(log_file=True, log_console=True, use_cache=True)

# %%
city = ox.gdf_from_place('Chicago, Illinois, USA')
city
# Out:
#    bbox_east  bbox_north  bbox_south  bbox_west  \
# 0 -87.523984   42.023022   41.643919 -87.940101
#
#                                             geometry  \
# 0  POLYGON ((-87.940101 42.000926, -87.940032 41....
#
#                                           place_name
# 0  Chicago, Cook County, Illinois, United States ...

# %%
city = ox.project_gdf(city)
fig, ax = ox.plot_shape(city)

# %%
city = ox.graph_from_address('60615')
fig, ax = ox.plot_graph(city)
