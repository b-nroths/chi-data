# %%
import requests as r
import pandas as pd

from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## start here!
## add eigenvectors to the network

eigenvalues_data = {}

datasets = [
    'final-homes-eigs-chicago-S000', 
    'final-homes-eigs-chicago-SA01', 
    'final-homes-eigs-chicago-SA02', 
    'final-homes-eigs-chicago-SA03', 
    'final-homes-eigs-chicago-SE01', 
    'final-homes-eigs-chicago-SE02', 
    'final-homes-eigs-chicago-SE03'
]

for dataset in datasets:
    for year in range(14):
        if dataset not in eigenvalues_data:
            eigenvalues_data[dataset] = {}
        
        year = year + 2002
        
        res = r.get('http://chicago.bnroths.com/data/%s/%s/1.json' % (dataset, year)).json()
        
        for a in res['data']:
            if a not in eigenvalues_data[dataset]:
                eigenvalues_data[dataset][a] = []
            eigenvalues_data[dataset][a].append(res['data'][a]['real'])

corrMatrix = pd.DataFrame()
print corrMatrix
for dataset in eigenvalues_data:
    for hood in sorted(eigenvalues_data[dataset]):   
        # print data[hood]
        # print data[hood]
        for i in range(len(eigenvalues_data[dataset][hood])):
            row = '%s-%s' % (hood, i)
            if i == 0:
                corrMatrix.at[row, dataset] = 0
            else:
                corrMatrix.at[row, dataset] = eigenvalues_data[dataset][hood][i] - eigenvalues_data[dataset][hood][i-1]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
corrMatrix
# Out:
#                          final-homes-eigs-chicago-SA01  \
# Albany Park-0                                      0.0
# Albany Park-1                                     16.2
# Albany Park-2                                    -24.1
# Albany Park-3                                    -15.5
# Albany Park-4                                      2.1
# Albany Park-5                                    -22.6
# Albany Park-6                                     30.0
# Albany Park-7                                    -37.5
# Albany Park-8                                     35.0
# Albany Park-9                                     24.4
# Albany Park-10                                    -2.6
# Albany Park-11                                    -4.1
# Albany Park-12                                   -20.4
# Albany Park-13                                   -10.1
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                 -7.5
# Altgeld Gardens-2                                  6.1
# Altgeld Gardens-3                                  5.3
# Altgeld Gardens-4                                 -3.7
# Altgeld Gardens-5                                  1.8
# Altgeld Gardens-6                                -10.3
# Altgeld Gardens-7                                  5.1
# Altgeld Gardens-8                                 -6.7
# Altgeld Gardens-9                                  1.9
# Altgeld Gardens-10                                -3.4
# Altgeld Gardens-11                                 3.0
# Altgeld Gardens-12                                 1.9
# Altgeld Gardens-13                                 0.0
# Andersonville-0                                    0.0
# Andersonville-1                                    2.1
# ...                                                ...
# Wrightwood-12                                      7.4
# Wrightwood-13                                      3.9
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                            -1.2
# Wrightwood Neighbors-2                             1.0
# Wrightwood Neighbors-3                             1.7
# Wrightwood Neighbors-4                            -0.3
# Wrightwood Neighbors-5                            -0.5
# Wrightwood Neighbors-6                             1.1
# Wrightwood Neighbors-7                            -6.0
# Wrightwood Neighbors-8                             6.9
# Wrightwood Neighbors-9                             1.6
# Wrightwood Neighbors-10                           -5.3
# Wrightwood Neighbors-11                            2.0
# Wrightwood Neighbors-12                            0.9
# Wrightwood Neighbors-13                           -5.2
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                    -4.4
# Wrigleyville-2                                     8.6
# Wrigleyville-3                                    -2.2
# Wrigleyville-4                                     6.2
# Wrigleyville-5                                    -1.7
# Wrigleyville-6                                     2.6
# Wrigleyville-7                                    -8.0
# Wrigleyville-8                                     6.3
# Wrigleyville-9                                    -4.1
# Wrigleyville-10                                    0.8
# Wrigleyville-11                                   -1.2
# Wrigleyville-12                                    1.9
# Wrigleyville-13                                   -3.0
#
#                          final-homes-eigs-chicago-SA03  \
# Albany Park-0                                      0.0
# Albany Park-1                                      8.3
# Albany Park-2                                     -4.5
# Albany Park-3                                      4.4
# Albany Park-4                                    -14.0
# Albany Park-5                                    -31.7
# Albany Park-6                                     58.5
# Albany Park-7                                    -55.3
# Albany Park-8                                     52.8
# Albany Park-9                                      5.2
# Albany Park-10                                    12.6
# Albany Park-11                                    -9.9
# Albany Park-12                                    -7.2
# Albany Park-13                                    11.3
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                  4.0
# Altgeld Gardens-2                                 -5.0
# Altgeld Gardens-3                                 11.2
# Altgeld Gardens-4                                  2.9
# Altgeld Gardens-5                                  1.2
# Altgeld Gardens-6                                -14.2
# Altgeld Gardens-7                                 11.8
# Altgeld Gardens-8                                -15.3
# Altgeld Gardens-9                                  2.7
# Altgeld Gardens-10                                -1.0
# Altgeld Gardens-11                                -1.5
# Altgeld Gardens-12                                -2.7
# Altgeld Gardens-13                                10.7
# Andersonville-0                                    0.0
# Andersonville-1                                   -6.6
# ...                                                ...
# Wrightwood-12                                      9.6
# Wrightwood-13                                     -1.3
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                             1.2
# Wrightwood Neighbors-2                            -0.4
# Wrightwood Neighbors-3                             2.3
# Wrightwood Neighbors-4                             1.6
# Wrightwood Neighbors-5                            -3.8
# Wrightwood Neighbors-6                            -1.8
# Wrightwood Neighbors-7                             0.8
# Wrightwood Neighbors-8                             4.3
# Wrightwood Neighbors-9                             1.0
# Wrightwood Neighbors-10                           -3.3
# Wrightwood Neighbors-11                            3.2
# Wrightwood Neighbors-12                           -1.5
# Wrightwood Neighbors-13                           -1.9
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                    -2.7
# Wrigleyville-2                                     1.5
# Wrigleyville-3                                     3.0
# Wrigleyville-4                                    -1.1
# Wrigleyville-5                                     3.4
# Wrigleyville-6                                    -7.6
# Wrigleyville-7                                     8.9
# Wrigleyville-8                                     0.5
# Wrigleyville-9                                    -4.6
# Wrigleyville-10                                    1.6
# Wrigleyville-11                                    0.6
# Wrigleyville-12                                   -0.9
# Wrigleyville-13                                    0.8
#
#                          final-homes-eigs-chicago-SA02  \
# Albany Park-0                                      0.0
# Albany Park-1                                      3.3
# Albany Park-2                                   -197.3
# Albany Park-3                                    190.4
# Albany Park-4                                    -13.5
# Albany Park-5                                    -28.5
# Albany Park-6                                     35.4
# Albany Park-7                                    -48.9
# Albany Park-8                                     59.2
# Albany Park-9                                      7.6
# Albany Park-10                                     6.2
# Albany Park-11                                   -10.0
# Albany Park-12                                    -6.2
# Albany Park-13                                    -5.8
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                  2.1
# Altgeld Gardens-2                                -27.5
# Altgeld Gardens-3                                 34.7
# Altgeld Gardens-4                                 -6.0
# Altgeld Gardens-5                                 -9.1
# Altgeld Gardens-6                                 -8.5
# Altgeld Gardens-7                                  6.7
# Altgeld Gardens-8                                 -2.0
# Altgeld Gardens-9                                 -5.9
# Altgeld Gardens-10                                 3.7
# Altgeld Gardens-11                                 0.3
# Altgeld Gardens-12                                -5.1
# Altgeld Gardens-13                                 8.1
# Andersonville-0                                    0.0
# Andersonville-1                                    0.9
# ...                                                ...
# Wrightwood-12                                     -4.1
# Wrightwood-13                                     -1.3
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                             0.1
# Wrightwood Neighbors-2                           -14.8
# Wrightwood Neighbors-3                            15.6
# Wrightwood Neighbors-4                            -0.3
# Wrightwood Neighbors-5                            -6.3
# Wrightwood Neighbors-6                             5.8
# Wrightwood Neighbors-7                            -3.3
# Wrightwood Neighbors-8                             7.1
# Wrightwood Neighbors-9                            -2.5
# Wrightwood Neighbors-10                            0.6
# Wrightwood Neighbors-11                            2.3
# Wrightwood Neighbors-12                           -3.7
# Wrightwood Neighbors-13                            2.2
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                     2.4
# Wrigleyville-2                                   -11.3
# Wrigleyville-3                                    11.0
# Wrigleyville-4                                     1.4
# Wrigleyville-5                                    -1.1
# Wrigleyville-6                                    -2.1
# Wrigleyville-7                                     3.3
# Wrigleyville-8                                     1.9
# Wrigleyville-9                                    -1.1
# Wrigleyville-10                                    1.2
# Wrigleyville-11                                    1.0
# Wrigleyville-12                                   -3.1
# Wrigleyville-13                                    2.4
#
#                          final-homes-eigs-chicago-SE01  \
# Albany Park-0                                      0.0
# Albany Park-1                                     24.6
# Albany Park-2                                      0.0
# Albany Park-3                                    -26.0
# Albany Park-4                                     -8.9
# Albany Park-5                                    -35.1
# Albany Park-6                                     35.9
# Albany Park-7                                    -38.6
# Albany Park-8                                     43.8
# Albany Park-9                                     15.4
# Albany Park-10                                    -4.6
# Albany Park-11                                    -0.6
# Albany Park-12                                   -20.5
# Albany Park-13                                   -13.1
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                 -2.4
# Altgeld Gardens-2                                  0.0
# Altgeld Gardens-3                                  5.1
# Altgeld Gardens-4                                 -1.2
# Altgeld Gardens-5                                 -0.2
# Altgeld Gardens-6                                -10.8
# Altgeld Gardens-7                                  9.2
# Altgeld Gardens-8                                 -9.6
# Altgeld Gardens-9                                  5.9
# Altgeld Gardens-10                                -5.3
# Altgeld Gardens-11                                 4.1
# Altgeld Gardens-12                                -7.7
# Altgeld Gardens-13                                13.1
# Andersonville-0                                    0.0
# Andersonville-1                                    2.4
# ...                                                ...
# Wrightwood-12                                      1.4
# Wrightwood-13                                      0.0
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                            -1.1
# Wrightwood Neighbors-2                             0.0
# Wrightwood Neighbors-3                             0.2
# Wrightwood Neighbors-4                            -1.4
# Wrightwood Neighbors-5                             0.0
# Wrightwood Neighbors-6                            -1.9
# Wrightwood Neighbors-7                             4.4
# Wrightwood Neighbors-8                            -0.5
# Wrightwood Neighbors-9                            -1.5
# Wrightwood Neighbors-10                           -0.4
# Wrightwood Neighbors-11                            2.1
# Wrightwood Neighbors-12                           -2.7
# Wrightwood Neighbors-13                            0.5
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                     0.9
# Wrigleyville-2                                     0.0
# Wrigleyville-3                                     0.0
# Wrigleyville-4                                    -0.4
# Wrigleyville-5                                     2.0
# Wrigleyville-6                                    -2.0
# Wrigleyville-7                                     0.4
# Wrigleyville-8                                     3.3
# Wrigleyville-9                                    -1.5
# Wrigleyville-10                                    0.2
# Wrigleyville-11                                   -1.4
# Wrigleyville-12                                    0.3
# Wrigleyville-13                                    0.2
#
#                          final-homes-eigs-chicago-SE03  \
# Albany Park-0                                      0.0
# Albany Park-1                                      1.7
# Albany Park-2                                      5.3
# Albany Park-3                                      4.9
# Albany Park-4                                     -6.7
# Albany Park-5                                     -5.2
# Albany Park-6                                     26.5
# Albany Park-7                                    -47.2
# Albany Park-8                                     39.8
# Albany Park-9                                     26.2
# Albany Park-10                                     0.6
# Albany Park-11                                    -1.0
# Albany Park-12                                   -13.7
# Albany Park-13                                     0.9
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                 -0.3
# Altgeld Gardens-2                                 -0.5
# Altgeld Gardens-3                                  8.3
# Altgeld Gardens-4                                 -0.3
# Altgeld Gardens-5                                 -8.0
# Altgeld Gardens-6                                 -0.2
# Altgeld Gardens-7                                  0.3
# Altgeld Gardens-8                                 -2.7
# Altgeld Gardens-9                                 -0.3
# Altgeld Gardens-10                                -0.1
# Altgeld Gardens-11                                 0.6
# Altgeld Gardens-12                                -0.1
# Altgeld Gardens-13                                 1.0
# Andersonville-0                                    0.0
# Andersonville-1                                   -7.3
# ...                                                ...
# Wrightwood-12                                     -2.1
# Wrightwood-13                                     -1.5
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                             1.6
# Wrightwood Neighbors-2                            -2.6
# Wrightwood Neighbors-3                            -3.9
# Wrightwood Neighbors-4                            -1.6
# Wrightwood Neighbors-5                           -19.6
# Wrightwood Neighbors-6                            13.9
# Wrightwood Neighbors-7                           -15.4
# Wrightwood Neighbors-8                            18.9
# Wrightwood Neighbors-9                            -7.1
# Wrightwood Neighbors-10                           -0.7
# Wrightwood Neighbors-11                           10.9
# Wrightwood Neighbors-12                           -3.4
# Wrightwood Neighbors-13                           -8.9
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                    -4.2
# Wrigleyville-2                                    -1.6
# Wrigleyville-3                                     2.8
# Wrigleyville-4                                    13.3
# Wrigleyville-5                                   -11.4
# Wrigleyville-6                                     0.5
# Wrigleyville-7                                     6.8
# Wrigleyville-8                                    -6.5
# Wrigleyville-9                                    -5.1
# Wrigleyville-10                                    1.7
# Wrigleyville-11                                    6.2
# Wrigleyville-12                                   -7.9
# Wrigleyville-13                                    1.9
#
#                          final-homes-eigs-chicago-SE02  \
# Albany Park-0                                      0.0
# Albany Park-1                                    -14.3
# Albany Park-2                                      3.9
# Albany Park-3                                    -14.9
# Albany Park-4                                    -14.0
# Albany Park-5                                    -23.2
# Albany Park-6                                     28.0
# Albany Park-7                                    -46.9
# Albany Park-8                                     57.8
# Albany Park-9                                      7.1
# Albany Park-10                                    10.3
# Albany Park-11                                   -11.1
# Albany Park-12                                    -4.3
# Albany Park-13                                   -10.0
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                  2.0
# Altgeld Gardens-2                                 -4.4
# Altgeld Gardens-3                                 16.3
# Altgeld Gardens-4                                 -8.0
# Altgeld Gardens-5                                 -1.4
# Altgeld Gardens-6                                -15.9
# Altgeld Gardens-7                                  8.1
# Altgeld Gardens-8                                 -1.3
# Altgeld Gardens-9                                 -7.8
# Altgeld Gardens-10                                 4.4
# Altgeld Gardens-11                                -1.2
# Altgeld Gardens-12                                -1.4
# Altgeld Gardens-13                                 5.8
# Andersonville-0                                    0.0
# Andersonville-1                                   -2.2
# ...                                                ...
# Wrightwood-12                                     -0.1
# Wrightwood-13                                      3.3
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                            -0.9
# Wrightwood Neighbors-2                             1.0
# Wrightwood Neighbors-3                             0.9
# Wrightwood Neighbors-4                             0.0
# Wrightwood Neighbors-5                            -1.9
# Wrightwood Neighbors-6                             1.5
# Wrightwood Neighbors-7                            -3.5
# Wrightwood Neighbors-8                             3.6
# Wrightwood Neighbors-9                             3.5
# Wrightwood Neighbors-10                           -3.5
# Wrightwood Neighbors-11                           -0.7
# Wrightwood Neighbors-12                            0.0
# Wrightwood Neighbors-13                           -0.2
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                    -1.2
# Wrigleyville-2                                     1.9
# Wrigleyville-3                                     0.1
# Wrigleyville-4                                     1.4
# Wrigleyville-5                                     0.5
# Wrigleyville-6                                    -2.8
# Wrigleyville-7                                     1.5
# Wrigleyville-8                                     0.9
# Wrigleyville-9                                    -2.0
# Wrigleyville-10                                    2.5
# Wrigleyville-11                                   -1.5
# Wrigleyville-12                                   -1.4
# Wrigleyville-13                                    0.2
#
#                          final-homes-eigs-chicago-S000
# Albany Park-0                                      0.0
# Albany Park-1                                      6.0
# Albany Park-2                                      0.0
# Albany Park-3                                    -15.6
# Albany Park-4                                     -7.0
# Albany Park-5                                    -28.5
# Albany Park-6                                     36.8
# Albany Park-7                                    -48.0
# Albany Park-8                                     53.1
# Albany Park-9                                     11.8
# Albany Park-10                                     3.5
# Albany Park-11                                    -8.0
# Albany Park-12                                    -9.8
# Albany Park-13                                    -4.1
# Altgeld Gardens-0                                  0.0
# Altgeld Gardens-1                                 -0.8
# Altgeld Gardens-2                                  0.0
# Altgeld Gardens-3                                  9.0
# Altgeld Gardens-4                                 -3.1
# Altgeld Gardens-5                                 -4.3
# Altgeld Gardens-6                                -10.9
# Altgeld Gardens-7                                  7.1
# Altgeld Gardens-8                                 -5.7
# Altgeld Gardens-9                                 -1.9
# Altgeld Gardens-10                                 0.6
# Altgeld Gardens-11                                 0.8
# Altgeld Gardens-12                                -3.0
# Altgeld Gardens-13                                 6.6
# Andersonville-0                                    0.0
# Andersonville-1                                    0.1
# ...                                                ...
# Wrightwood-12                                      0.7
# Wrightwood-13                                      0.7
# Wrightwood Neighbors-0                             0.0
# Wrightwood Neighbors-1                            -0.4
# Wrightwood Neighbors-2                             0.0
# Wrightwood Neighbors-3                             1.6
# Wrightwood Neighbors-4                             0.3
# Wrightwood Neighbors-5                            -4.2
# Wrightwood Neighbors-6                             3.1
# Wrightwood Neighbors-7                            -3.9
# Wrightwood Neighbors-8                             6.7
# Wrightwood Neighbors-9                            -0.7
# Wrightwood Neighbors-10                           -1.4
# Wrightwood Neighbors-11                            2.0
# Wrightwood Neighbors-12                           -1.9
# Wrightwood Neighbors-13                           -0.4
# Wrigleyville-0                                     0.0
# Wrigleyville-1                                    -0.2
# Wrigleyville-2                                     0.0
# Wrigleyville-3                                     2.4
# Wrigleyville-4                                     3.1
# Wrigleyville-5                                    -1.5
# Wrigleyville-6                                    -1.5
# Wrigleyville-7                                     0.9
# Wrigleyville-8                                     2.8
# Wrigleyville-9                                    -2.8
# Wrigleyville-10                                    1.4
# Wrigleyville-11                                    0.2
# Wrigleyville-12                                   -1.2
# Wrigleyville-13                                    0.6
#
# [2657 rows x 7 columns]

# %%
files = [
    'Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv', 
    'Neighborhood_Zri_AllHomesPlusMultifamily.csv',
    'Neighborhood_Zhvi_AllHomes.csv', 
]

def normal(row):
    if row.name == 'RegionName':
        return row
    else:
        return row.divide(sum(row.fillna(0))/len(row))

def sub(row):
    print row.append(pd.series([0, 1, 2]))
    return row.subtract(row)

for filename in files:
    print filename
    zillow = pd.read_csv('zillow_data/%s' % filename)
    # print zillow.index
    ## first normalize by column average
    
    try:
        zillow = zillow[(zillow.City == 'Chicago')][[
            'RegionName',
            '2002-01',
            '2003-01',
            '2004-01',
            '2005-01',
            '2006-01',
            '2007-01',
            '2008-01',
            '2009-01',
            '2010-01',
            '2011-01',
            '2012-01',
            '2013-01',
            '2014-01',
            '2015-01']]
    except:
        # rent index starts in 2010
        zillow = zillow[(zillow.City == 'Chicago')][[
            'RegionName',
            '2011-01',
            '2012-01',
            '2013-01',
            '2014-01',
            '2015-01']]

        
    zillow = zillow.transpose().apply(normal, axis=1)
    zillow = zillow.rename(columns=zillow.iloc[0]).drop(zillow.index[:1]).transpose()
    print zillow.apply(sub, axis=1)
    #for index, row in zillow.iterrows():
    #    rows = list(row)
    #    
    #    for i, val in enumerate(rows):
    #        if len(rows) == 5:
    #            i += 9
    #        row = "%s-%s" % (index, i)
    #        # print row, val, dataset
    #        corrMatrix.at[row, filename] = val
# Out:
# Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-87d6b5383761> in <module>()
#      52     zillow = zillow.transpose().apply(normal, axis=1)
#      53     zillow = zillow.rename(columns=zillow.iloc[0]).drop(zillow.index[:1]).transpose()
# ---> 54     print zillow.apply(sub, axis=1)
#      55     #for index, row in zillow.iterrows():
#      56     #    rows = list(row)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
#    4975             except Exception as e:
#
# <ipython-input-44-87d6b5383761> in sub(row)
#      13 def sub(row):
#      14 #     print row
# ---> 15     print row.append(pd.series([0, 1, 2]))
#      16     return row.subtract(row)
#      17
#
# AttributeError: ("'module' object has no attribute 'series'", u'occurred at index Logan Square')

# %%
corrMatrix = corrMatrix[corrMatrix.index.str.contains("-0") == False]

# %%
zillow_test = pd.read_csv('zillow_data/Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv')
zillow_test[(zillow_test.RegionName == 'South Loop')][['2002-01', '2003-01']].head()
# Out:
#      2002-01  2003-01
# 220    80.79     87.8

# %%
corrMatrix.dropna()
# Out:
#                          final-homes-eigs-chicago-SA01  \
# Albany Park-0                                    187.0
# Albany Park-1                                    203.2
# Albany Park-2                                    179.1
# Albany Park-3                                    163.6
# Albany Park-4                                    165.7
# Albany Park-5                                    143.1
# Albany Park-6                                    173.1
# Albany Park-7                                    135.6
# Albany Park-8                                    170.6
# Albany Park-9                                    195.0
# Albany Park-10                                   192.4
# Albany Park-11                                   188.3
# Albany Park-12                                   167.9
# Albany Park-13                                   157.8
# Andersonville-0                                   25.3
# Andersonville-1                                   27.4
# Andersonville-2                                   27.9
# Andersonville-3                                   21.9
# Andersonville-4                                   22.9
# Andersonville-5                                   23.6
# Andersonville-6                                   21.2
# Andersonville-7                                   20.4
# Andersonville-8                                   25.1
# Andersonville-9                                   23.7
# Andersonville-10                                  25.5
# Andersonville-11                                  21.9
# Andersonville-12                                  22.3
# Andersonville-13                                  17.8
# Archer Heights-0                                 196.6
# Archer Heights-1                                 184.1
# ...                                                ...
# Wrightwood-12                                     31.1
# Wrightwood-13                                     35.0
# Wrightwood Neighbors-0                            23.4
# Wrightwood Neighbors-1                            22.2
# Wrightwood Neighbors-2                            23.2
# Wrightwood Neighbors-3                            24.9
# Wrightwood Neighbors-4                            24.6
# Wrightwood Neighbors-5                            24.1
# Wrightwood Neighbors-6                            25.2
# Wrightwood Neighbors-7                            19.2
# Wrightwood Neighbors-8                            26.1
# Wrightwood Neighbors-9                            27.7
# Wrightwood Neighbors-10                           22.4
# Wrightwood Neighbors-11                           24.4
# Wrightwood Neighbors-12                           25.3
# Wrightwood Neighbors-13                           20.1
# Wrigleyville-0                                    19.8
# Wrigleyville-1                                    15.4
# Wrigleyville-2                                    24.0
# Wrigleyville-3                                    21.8
# Wrigleyville-4                                    28.0
# Wrigleyville-5                                    26.3
# Wrigleyville-6                                    28.9
# Wrigleyville-7                                    20.9
# Wrigleyville-8                                    27.2
# Wrigleyville-9                                    23.1
# Wrigleyville-10                                   23.9
# Wrigleyville-11                                   22.7
# Wrigleyville-12                                   24.6
# Wrigleyville-13                                   21.6
#
#                          final-homes-eigs-chicago-SA03  \
# Albany Park-0                                    155.4
# Albany Park-1                                    163.7
# Albany Park-2                                    159.2
# Albany Park-3                                    163.6
# Albany Park-4                                    149.6
# Albany Park-5                                    117.9
# Albany Park-6                                    176.4
# Albany Park-7                                    121.1
# Albany Park-8                                    173.9
# Albany Park-9                                    179.1
# Albany Park-10                                   191.7
# Albany Park-11                                   181.8
# Albany Park-12                                   174.6
# Albany Park-13                                   185.9
# Andersonville-0                                   24.7
# Andersonville-1                                   18.1
# Andersonville-2                                   25.1
# Andersonville-3                                   22.7
# Andersonville-4                                   23.0
# Andersonville-5                                   13.8
# Andersonville-6                                   27.2
# Andersonville-7                                   14.3
# Andersonville-8                                   24.9
# Andersonville-9                                   29.0
# Andersonville-10                                  24.1
# Andersonville-11                                  24.7
# Andersonville-12                                  26.3
# Andersonville-13                                  19.2
# Archer Heights-0                                 158.5
# Archer Heights-1                                 156.4
# ...                                                ...
# Wrightwood-12                                     61.3
# Wrightwood-13                                     60.0
# Wrightwood Neighbors-0                            11.3
# Wrightwood Neighbors-1                            12.5
# Wrightwood Neighbors-2                            12.1
# Wrightwood Neighbors-3                            14.4
# Wrightwood Neighbors-4                            16.0
# Wrightwood Neighbors-5                            12.2
# Wrightwood Neighbors-6                            10.4
# Wrightwood Neighbors-7                            11.2
# Wrightwood Neighbors-8                            15.5
# Wrightwood Neighbors-9                            16.5
# Wrightwood Neighbors-10                           13.2
# Wrightwood Neighbors-11                           16.4
# Wrightwood Neighbors-12                           14.9
# Wrightwood Neighbors-13                           13.0
# Wrigleyville-0                                     7.3
# Wrigleyville-1                                     4.6
# Wrigleyville-2                                     6.1
# Wrigleyville-3                                     9.1
# Wrigleyville-4                                     8.0
# Wrigleyville-5                                    11.4
# Wrigleyville-6                                     3.8
# Wrigleyville-7                                    12.7
# Wrigleyville-8                                    13.2
# Wrigleyville-9                                     8.6
# Wrigleyville-10                                   10.2
# Wrigleyville-11                                   10.8
# Wrigleyville-12                                    9.9
# Wrigleyville-13                                   10.7
#
#                          final-homes-eigs-chicago-SA02  \
# Albany Park-0                                    194.0
# Albany Park-1                                    197.3
# Albany Park-2                                      0.0
# Albany Park-3                                    190.4
# Albany Park-4                                    176.9
# Albany Park-5                                    148.4
# Albany Park-6                                    183.8
# Albany Park-7                                    134.9
# Albany Park-8                                    194.1
# Albany Park-9                                    201.7
# Albany Park-10                                   207.9
# Albany Park-11                                   197.9
# Albany Park-12                                   191.7
# Albany Park-13                                   185.9
# Andersonville-0                                   29.0
# Andersonville-1                                   29.9
# Andersonville-2                                    0.0
# Andersonville-3                                   27.4
# Andersonville-4                                   33.5
# Andersonville-5                                   19.7
# Andersonville-6                                   27.2
# Andersonville-7                                   24.1
# Andersonville-8                                   28.4
# Andersonville-9                                   30.4
# Andersonville-10                                  31.9
# Andersonville-11                                  27.5
# Andersonville-12                                  27.1
# Andersonville-13                                  30.1
# Archer Heights-0                                 176.7
# Archer Heights-1                                 173.7
# ...                                                ...
# Wrightwood-12                                     34.4
# Wrightwood-13                                     33.1
# Wrightwood Neighbors-0                            14.7
# Wrightwood Neighbors-1                            14.8
# Wrightwood Neighbors-2                             0.0
# Wrightwood Neighbors-3                            15.6
# Wrightwood Neighbors-4                            15.3
# Wrightwood Neighbors-5                             9.0
# Wrightwood Neighbors-6                            14.8
# Wrightwood Neighbors-7                            11.5
# Wrightwood Neighbors-8                            18.6
# Wrightwood Neighbors-9                            16.1
# Wrightwood Neighbors-10                           16.7
# Wrightwood Neighbors-11                           19.0
# Wrightwood Neighbors-12                           15.3
# Wrightwood Neighbors-13                           17.5
# Wrigleyville-0                                     8.9
# Wrigleyville-1                                    11.3
# Wrigleyville-2                                     0.0
# Wrigleyville-3                                    11.0
# Wrigleyville-4                                    12.4
# Wrigleyville-5                                    11.3
# Wrigleyville-6                                     9.2
# Wrigleyville-7                                    12.5
# Wrigleyville-8                                    14.4
# Wrigleyville-9                                    13.3
# Wrigleyville-10                                   14.5
# Wrigleyville-11                                   15.5
# Wrigleyville-12                                   12.4
# Wrigleyville-13                                   14.8
#
#                          final-homes-eigs-chicago-SE01  \
# Albany Park-0                                    167.5
# Albany Park-1                                    192.1
# Albany Park-2                                    192.1
# Albany Park-3                                    166.1
# Albany Park-4                                    157.2
# Albany Park-5                                    122.1
# Albany Park-6                                    158.0
# Albany Park-7                                    119.4
# Albany Park-8                                    163.2
# Albany Park-9                                    178.6
# Albany Park-10                                   174.0
# Albany Park-11                                   173.4
# Albany Park-12                                   152.9
# Albany Park-13                                   139.8
# Andersonville-0                                   19.4
# Andersonville-1                                   21.8
# Andersonville-2                                   21.8
# Andersonville-3                                   19.0
# Andersonville-4                                   23.2
# Andersonville-5                                   16.9
# Andersonville-6                                   20.2
# Andersonville-7                                   12.9
# Andersonville-8                                   21.9
# Andersonville-9                                   21.1
# Andersonville-10                                  21.5
# Andersonville-11                                  21.4
# Andersonville-12                                  18.1
# Andersonville-13                                  17.4
# Archer Heights-0                                 188.9
# Archer Heights-1                                 203.5
# ...                                                ...
# Wrightwood-12                                     39.7
# Wrightwood-13                                     39.7
# Wrightwood Neighbors-0                            11.5
# Wrightwood Neighbors-1                            10.4
# Wrightwood Neighbors-2                            10.4
# Wrightwood Neighbors-3                            10.6
# Wrightwood Neighbors-4                             9.2
# Wrightwood Neighbors-5                             9.2
# Wrightwood Neighbors-6                             7.3
# Wrightwood Neighbors-7                            11.7
# Wrightwood Neighbors-8                            11.2
# Wrightwood Neighbors-9                             9.7
# Wrightwood Neighbors-10                            9.3
# Wrightwood Neighbors-11                           11.4
# Wrightwood Neighbors-12                            8.7
# Wrightwood Neighbors-13                            9.2
# Wrigleyville-0                                     7.7
# Wrigleyville-1                                     8.6
# Wrigleyville-2                                     8.6
# Wrigleyville-3                                     8.6
# Wrigleyville-4                                     8.2
# Wrigleyville-5                                    10.2
# Wrigleyville-6                                     8.2
# Wrigleyville-7                                     8.6
# Wrigleyville-8                                    11.9
# Wrigleyville-9                                    10.4
# Wrigleyville-10                                   10.6
# Wrigleyville-11                                    9.2
# Wrigleyville-12                                    9.5
# Wrigleyville-13                                    9.7
#
#                          final-homes-eigs-chicago-SE03  \
# Albany Park-0                                    159.1
# Albany Park-1                                    160.8
# Albany Park-2                                    166.1
# Albany Park-3                                    171.0
# Albany Park-4                                    164.3
# Albany Park-5                                    159.1
# Albany Park-6                                    185.6
# Albany Park-7                                    138.4
# Albany Park-8                                    178.2
# Albany Park-9                                    204.4
# Albany Park-10                                   205.0
# Albany Park-11                                   204.0
# Albany Park-12                                   190.3
# Albany Park-13                                   191.2
# Andersonville-0                                   63.0
# Andersonville-1                                   55.7
# Andersonville-2                                   57.2
# Andersonville-3                                   61.0
# Andersonville-4                                   68.6
# Andersonville-5                                   44.1
# Andersonville-6                                   57.3
# Andersonville-7                                   59.4
# Andersonville-8                                   52.1
# Andersonville-9                                   54.4
# Andersonville-10                                  48.0
# Andersonville-11                                  53.6
# Andersonville-12                                  53.1
# Andersonville-13                                  51.4
# Archer Heights-0                                 130.0
# Archer Heights-1                                 110.6
# ...                                                ...
# Wrightwood-12                                     32.7
# Wrightwood-13                                     31.2
# Wrightwood Neighbors-0                            58.0
# Wrightwood Neighbors-1                            59.6
# Wrightwood Neighbors-2                            57.0
# Wrightwood Neighbors-3                            53.1
# Wrightwood Neighbors-4                            51.5
# Wrightwood Neighbors-5                            31.9
# Wrightwood Neighbors-6                            45.8
# Wrightwood Neighbors-7                            30.4
# Wrightwood Neighbors-8                            49.3
# Wrightwood Neighbors-9                            42.2
# Wrightwood Neighbors-10                           41.5
# Wrightwood Neighbors-11                           52.4
# Wrightwood Neighbors-12                           49.0
# Wrightwood Neighbors-13                           40.1
# Wrigleyville-0                                    33.4
# Wrigleyville-1                                    29.2
# Wrigleyville-2                                    27.6
# Wrigleyville-3                                    30.4
# Wrigleyville-4                                    43.7
# Wrigleyville-5                                    32.3
# Wrigleyville-6                                    32.8
# Wrigleyville-7                                    39.6
# Wrigleyville-8                                    33.1
# Wrigleyville-9                                    28.0
# Wrigleyville-10                                   29.7
# Wrigleyville-11                                   35.9
# Wrigleyville-12                                   28.0
# Wrigleyville-13                                   29.9
#
#                          final-homes-eigs-chicago-SE02  \
# Albany Park-0                                    197.6
# Albany Park-1                                    183.3
# Albany Park-2                                    187.2
# Albany Park-3                                    172.3
# Albany Park-4                                    158.3
# Albany Park-5                                    135.1
# Albany Park-6                                    163.1
# Albany Park-7                                    116.2
# Albany Park-8                                    174.0
# Albany Park-9                                    181.1
# Albany Park-10                                   191.4
# Albany Park-11                                   180.3
# Albany Park-12                                   176.0
# Albany Park-13                                   166.0
# Andersonville-0                                   25.0
# Andersonville-1                                   22.8
# Andersonville-2                                   23.1
# Andersonville-3                                   18.7
# Andersonville-4                                   21.7
# Andersonville-5                                   13.6
# Andersonville-6                                   18.0
# Andersonville-7                                   14.3
# Andersonville-8                                   17.8
# Andersonville-9                                   21.3
# Andersonville-10                                  22.8
# Andersonville-11                                  15.6
# Andersonville-12                                  17.4
# Andersonville-13                                  15.4
# Archer Heights-0                                 184.2
# Archer Heights-1                                 173.1
# ...                                                ...
# Wrightwood-12                                     36.1
# Wrightwood-13                                     39.4
# Wrightwood Neighbors-0                            10.5
# Wrightwood Neighbors-1                             9.6
# Wrightwood Neighbors-2                            10.6
# Wrightwood Neighbors-3                            11.5
# Wrightwood Neighbors-4                            11.5
# Wrightwood Neighbors-5                             9.6
# Wrightwood Neighbors-6                            11.1
# Wrightwood Neighbors-7                             7.6
# Wrightwood Neighbors-8                            11.2
# Wrightwood Neighbors-9                            14.7
# Wrightwood Neighbors-10                           11.2
# Wrightwood Neighbors-11                           10.5
# Wrightwood Neighbors-12                           10.5
# Wrightwood Neighbors-13                           10.3
# Wrigleyville-0                                     9.7
# Wrigleyville-1                                     8.5
# Wrigleyville-2                                    10.4
# Wrigleyville-3                                    10.5
# Wrigleyville-4                                    11.9
# Wrigleyville-5                                    12.4
# Wrigleyville-6                                     9.6
# Wrigleyville-7                                    11.1
# Wrigleyville-8                                    12.0
# Wrigleyville-9                                    10.0
# Wrigleyville-10                                   12.5
# Wrigleyville-11                                   11.0
# Wrigleyville-12                                    9.6
# Wrigleyville-13                                    9.8
#
#                          final-homes-eigs-chicago-S000  \
# Albany Park-0                                    188.9
# Albany Park-1                                    194.9
# Albany Park-2                                    194.9
# Albany Park-3                                    179.3
# Albany Park-4                                    172.3
# Albany Park-5                                    143.8
# Albany Park-6                                    180.6
# Albany Park-7                                    132.6
# Albany Park-8                                    185.7
# Albany Park-9                                    197.5
# Albany Park-10                                   201.0
# Albany Park-11                                   193.0
# Albany Park-12                                   183.2
# Albany Park-13                                   179.1
# Andersonville-0                                   27.4
# Andersonville-1                                   27.5
# Andersonville-2                                   27.5
# Andersonville-3                                   24.9
# Andersonville-4                                   29.1
# Andersonville-5                                   20.0
# Andersonville-6                                   25.9
# Andersonville-7                                   21.1
# Andersonville-8                                   27.2
# Andersonville-9                                   28.7
# Andersonville-10                                  28.6
# Andersonville-11                                  25.6
# Andersonville-12                                  25.6
# Andersonville-13                                  24.7
# Archer Heights-0                                 181.5
# Archer Heights-1                                 178.0
# ...                                                ...
# Wrightwood-12                                     38.5
# Wrightwood-13                                     39.2
# Wrightwood Neighbors-0                            16.8
# Wrightwood Neighbors-1                            16.4
# Wrightwood Neighbors-2                            16.4
# Wrightwood Neighbors-3                            18.0
# Wrightwood Neighbors-4                            18.3
# Wrightwood Neighbors-5                            14.1
# Wrightwood Neighbors-6                            17.2
# Wrightwood Neighbors-7                            13.3
# Wrightwood Neighbors-8                            20.0
# Wrightwood Neighbors-9                            19.3
# Wrightwood Neighbors-10                           17.9
# Wrightwood Neighbors-11                           19.9
# Wrightwood Neighbors-12                           18.0
# Wrightwood Neighbors-13                           17.6
# Wrigleyville-0                                    11.6
# Wrigleyville-1                                    11.4
# Wrigleyville-2                                    11.4
# Wrigleyville-3                                    13.8
# Wrigleyville-4                                    16.9
# Wrigleyville-5                                    15.4
# Wrigleyville-6                                    13.9
# Wrigleyville-7                                    14.8
# Wrigleyville-8                                    17.6
# Wrigleyville-9                                    14.8
# Wrigleyville-10                                   16.2
# Wrigleyville-11                                   16.4
# Wrigleyville-12                                   15.2
# Wrigleyville-13                                   15.8
#
#                          Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv  \
# Albany Park-0                                                     1.000000
# Albany Park-1                                                     1.369288
# Albany Park-2                                                     1.158024
# Albany Park-3                                                     1.194491
# Albany Park-4                                                     1.237575
# Albany Park-5                                                     0.688260
# Albany Park-6                                                     0.766272
# Albany Park-7                                                     0.183105
# Albany Park-8                                                     0.236498
# Albany Park-9                                                     0.147869
# Albany Park-10                                                    0.247423
# Albany Park-11                                                    0.474381
# Albany Park-12                                                    1.346823
# Albany Park-13                                                    0.753193
# Andersonville-0                                                   1.000000
# Andersonville-1                                                   1.349263
# Andersonville-2                                                   0.811401
# Andersonville-3                                                   1.012195
# Andersonville-4                                                   1.245462
# Andersonville-5                                                   0.778219
# Andersonville-6                                                   0.239507
# Andersonville-7                                                   0.343732
# Andersonville-8                                                   0.384855
# Andersonville-9                                                   0.171724
# Andersonville-10                                                  0.171724
# Andersonville-11                                                  0.615712
# Andersonville-12                                                  1.204906
# Andersonville-13                                                  1.071611
# Archer Heights-0                                                  1.000000
# Archer Heights-1                                                  1.274750
# ...                                                                    ...
# Wrightwood-12                                                     0.854573
# Wrightwood-13                                                     0.755267
# Wrightwood Neighbors-0                                            1.000000
# Wrightwood Neighbors-1                                            1.624605
# Wrightwood Neighbors-2                                            0.766588
# Wrightwood Neighbors-3                                            1.691548
# Wrightwood Neighbors-4                                            1.628160
# Wrightwood Neighbors-5                                            0.689573
# Wrightwood Neighbors-6                                            0.682267
# Wrightwood Neighbors-7                                            0.459123
# Wrightwood Neighbors-8                                            0.585308
# Wrightwood Neighbors-9                                            0.372235
# Wrightwood Neighbors-10                                           0.380529
# Wrightwood Neighbors-11                                           1.081951
# Wrightwood Neighbors-12                                           1.733412
# Wrightwood Neighbors-13                                           0.860782
# Wrigleyville-0                                                    1.000000
# Wrigleyville-1                                                    2.163195
# Wrigleyville-2                                                    1.212448
# Wrigleyville-3                                                    2.066895
# Wrigleyville-4                                                    1.701054
# Wrigleyville-5                                                    1.023034
# Wrigleyville-6                                                    0.966430
# Wrigleyville-7                                                    0.413379
# Wrigleyville-8                                                    0.590542
# Wrigleyville-9                                                    0.200686
# Wrigleyville-10                                                   0.336437
# Wrigleyville-11                                                   1.411174
# Wrigleyville-12                                                   2.202401
# Wrigleyville-13                                                   1.369762
#
#                          Neighborhood_Zhvi_AllHomes.csv
# Albany Park-0                                  1.000000
# Albany Park-1                                  1.121352
# Albany Park-2                                  1.162267
# Albany Park-3                                  1.294877
# Albany Park-4                                  1.388397
# Albany Park-5                                  1.399587
# Albany Park-6                                  1.410198
# Albany Park-7                                  1.202876
# Albany Park-8                                  1.004537
# Albany Park-9                                  0.931357
# Albany Park-10                                 0.806427
# Albany Park-11                                 0.810796
# Albany Park-12                                 0.928579
# Albany Park-13                                 0.996402
# Andersonville-0                                1.000000
# Andersonville-1                                1.036751
# Andersonville-2                                1.112741
# Andersonville-3                                1.201380
# Andersonville-4                                1.292040
# Andersonville-5                                1.260134
# Andersonville-6                                1.239935
# Andersonville-7                                1.124173
# Andersonville-8                                1.109739
# Andersonville-9                                1.039498
# Andersonville-10                               0.982517
# Andersonville-11                               1.007635
# Andersonville-12                               1.062571
# Andersonville-13                               1.105010
# Archer Heights-0                               1.000000
# Archer Heights-1                               1.099747
# ...                                                 ...
# Wrightwood-12                                  1.117921
# Wrightwood-13                                  1.133194
# Wrightwood Neighbors-0                         1.000000
# Wrightwood Neighbors-1                         1.025535
# Wrightwood Neighbors-2                         1.037600
# Wrightwood Neighbors-3                         1.113450
# Wrightwood Neighbors-4                         1.163213
# Wrightwood Neighbors-5                         1.178928
# Wrightwood Neighbors-6                         1.135570
# Wrightwood Neighbors-7                         1.058300
# Wrightwood Neighbors-8                         1.016832
# Wrightwood Neighbors-9                         0.961095
# Wrightwood Neighbors-10                        0.946173
# Wrightwood Neighbors-11                        1.026353
# Wrightwood Neighbors-12                        1.081615
# Wrightwood Neighbors-13                        1.094635
# Wrigleyville-0                                 1.000000
# Wrigleyville-1                                 1.029262
# Wrigleyville-2                                 1.079600
# Wrigleyville-3                                 1.145477
# Wrigleyville-4                                 1.202493
# Wrigleyville-5                                 1.214006
# Wrigleyville-6                                 1.138136
# Wrigleyville-7                                 1.062760
# Wrigleyville-8                                 1.035326
# Wrigleyville-9                                 0.961466
# Wrigleyville-10                                0.954478
# Wrigleyville-11                                0.981104
# Wrigleyville-12                                1.059166
# Wrigleyville-13                                1.073593
#
# [1554 rows x 9 columns]

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="white")

# Compute the correlation matrix
corr = corrMatrix.corr()

# Generate a mask for the upper triangle
#mask = np.zeros_like(corr, dtype=np.bool)
#mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(10, 220, as_cmap=True)
print cmap

corr_small = corr.loc[['Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv', 'Neighborhood_Zhvi_AllHomes.csv', 'Neighborhood_Zri_AllHomesPlusMultifamily.csv']][[
    'final-homes-eigs-chicago-S000', 
    'final-homes-eigs-chicago-SA01', 
    'final-homes-eigs-chicago-SA02', 
    'final-homes-eigs-chicago-SA03', 
    'final-homes-eigs-chicago-SE01', 
    'final-homes-eigs-chicago-SE02', 
    'final-homes-eigs-chicago-SE03']]
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_small, 
            #mask=mask, 
            annot=True, 
            cmap=cmap, 
            center=0, 
            square=True, 
            linewidths=.5, 
            cbar_kws={"shrink": .5})
# Out:
# <matplotlib.colors.LinearSegmentedColormap object at 0x1072cb210>

# %%
corr.loc[['Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv', 'Neighborhood_Zhvi_AllHomes.csv', 'Neighborhood_Zri_AllHomesPlusMultifamily.csv']][[
    'final-homes-eigs-chicago-S000', 
    'final-homes-eigs-chicago-SA01', 
    'final-homes-eigs-chicago-SA02', 
    'final-homes-eigs-chicago-SA03', 
    'final-homes-eigs-chicago-SE01', 
    'final-homes-eigs-chicago-SE02', 
    'final-homes-eigs-chicago-SE03']]
# Out:
#                                                     final-homes-eigs-chicago-S000  \
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                       0.019843
# Neighborhood_Zhvi_AllHomes.csv                                           0.001264
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.088460
#
#                                                     final-homes-eigs-chicago-SA01  \
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                       0.025323
# Neighborhood_Zhvi_AllHomes.csv                                          -0.011302
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.144651
#
#                                                     final-homes-eigs-chicago-SA02  \
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                      -0.008793
# Neighborhood_Zhvi_AllHomes.csv                                           0.006779
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.006933
#
#                                                     final-homes-eigs-chicago-SA03  \
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                      -0.005398
# Neighborhood_Zhvi_AllHomes.csv                                           0.002314
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.054476
#
#                                                     final-homes-eigs-chicago-SE01  \
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                      -0.017176
# Neighborhood_Zhvi_AllHomes.csv                                          -0.024566
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.117792
#
#                                                     final-homes-eigs-chicago-SE02  \
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                       0.017936
# Neighborhood_Zhvi_AllHomes.csv                                          -0.016804
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.054995
#
#                                                     final-homes-eigs-chicago-SE03
# Neighborhood_PctOfHomesIncreasingInValues_AllHo...                       0.044227
# Neighborhood_Zhvi_AllHomes.csv                                           0.008358
# Neighborhood_Zri_AllHomesPlusMultifamily.csv                            -0.013178

# %%
sns.pairplot(corrMatrix)
sns.plt.show()
# Out:
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /usr/local/lib/python2.7/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-07ba548d2046> in <module>()
# ----> 1 sns.pairplot(corrMatrix)
#       2 sns.plt.show()
#
# /usr/local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2058     if grid.square_grid:
#    2059         if diag_kind == "hist":
# -> 2060             grid.map_diag(plt.hist, **diag_kws)
#    2061         elif diag_kind == "kde":
#    2062             diag_kws["legend"] = False
#
# /usr/local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_diag(self, func, **kwargs)
#    1363                     func(vals, color=color, **kwargs)
#    1364                 else:
# -> 1365                     func(vals, color=color, histtype="barstacked", **kwargs)
#    1366
#    1367             else:
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
#    3131                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3132                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3133     finally:
#    3134         ax._hold = washold
#
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(***failed resolving arguments***)
#    6528             # this will automatically overwrite bins,
#    6529             # so that each histogram uses the same bins
# -> 6530             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6531             m = m.astype(float)  # causes problems later if it's an int
#    6532             if mlast is None:
#
# /usr/local/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     665     if first_edge > last_edge:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([first_edge, last_edge])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
iris
# g = sns.pairplot(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
corrMatrix.columns
# Out:
# Index([u'final-homes-eigs-chicago-SA01', u'final-homes-eigs-chicago-SA03',
#        u'final-homes-eigs-chicago-SA02', u'final-homes-eigs-chicago-SE01',
#        u'final-homes-eigs-chicago-SE03', u'final-homes-eigs-chicago-SE02',
#        u'final-homes-eigs-chicago-S000',
#        u'Neighborhood_PctOfHomesIncreasingInValues_AllHomes.csv',
#        u'Neighborhood_Zri_AllHomesPlusMultifamily.csv',
#        u'Neighborhood_Zhvi_AllHomes.csv'],
#       dtype='object')
